# %% [markdown]
# # Final Project for data science course at GA
# by A. Albert Nelson

# %% [markdown]
# ### Problem statement
#
# Predict how many trips will end at a given location in a given duration of time based on the past history of trips made.

# %% [markdown]
# ### Data availability
# New york city taxi trip data is available at https://www.kaggle.com/c/nyc-taxi-trip-duration/data (six months)

# %% [markdown]
# ### Feature Engineering
# - Trip distance
# - Binning of GPS co-ordinates into regions of 1km by 1km
# - Binning of time into 15 minutes slots, weekday
#
#
# ### Models tried
# Linear regression
#    - OLS
#    - SVR
#      - With scaler
#
# Time series
#    - ARIMA
#    - Prophet

# %% [markdown]
# ### Regression models RMSE values
#
# - Linear Regression : 26.829107457476027
#
#
#
# - Support Vector Regression with scale : 27.603133033032044
#
#
# - Null: 27.162845138090184

# %%
predict_using_ARIMA(tfdf['trips_count'].values, 0.75, (5,0,0))
# Out:
# ARIMA params: (5, 0, 0)
# RMSE: 2.375083082578837
# NULL RMSE that just predicts the training mean: 2.639265537661475

# %%
predict_using_Prophet_logistic(tfdf,0.75,'Prophet logistic prediction')
# Out:
# Prophet logistic prediction
# RMSE: 2.3931045270710403
# NULL RMSE that just predicts the training mean: 2.639265537661475

# %% [markdown]
# ### Model deployment
# - Pickle to store as serialized objects
# - Function to load the objects and predict

# %% [markdown]
# ## Thank you
