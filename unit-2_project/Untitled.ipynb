# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape
# Out:
# (979, 6)

# %%
import numpy as np

# %%
d = np.zeros((2,), dtype=[('A', 'i4'),('B', 'f4'),('C', 'a10')])

# %%
d
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame(d)
# Out:
#    A    B    C
# 0  0  0.0  b''
# 1  0  0.0  b''

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.sort_values('duration').tail(1)
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10dd48f28>,
# ...
#       dtype=object)

# %%
movies.duration.hist()

# %%
plt.boxplot([1,1,2,2,3,3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10eaa62e8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10eaa6ba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x10eaa6198>],
#  'medians': [<matplotlib.lines.Line2D at 0x10eab0438>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10eab0860>],
#  'means': []}

# %%
movies.duration.plot(kind='box')

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.groupby('content_rating').count()
# Out:
#                 star_rating  title  genre  duration  actors_list
# content_rating
# APPROVED                 47     47     47        47           47
# G                        32     32     32        32           32
# GP                        3      3      3         3            3
# NC-17                     7      7      7         7            7
# NOT RATED                65     65     65        65           65
# PASSED                    7      7      7         7            7
# PG                      123    123    123       123          123
# PG-13                   189    189    189       189          189
# R                       460    460    460       460          460
# TV-MA                     1      1      1         1            1
# UNRATED                  38     38     38        38           38
# X                         4      4      4         4            4

# %%
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
movies.content_rating.hist()

# %%
plt.bar(x=['A','B','A'], height=[10,20,15])
# Out:
# <BarContainer object of 3 artists>

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(*args, **kwargs)
#     Make a bar plot.
#
#     Call signatures::
#
#        bar(x, height, *, align='center', **kwargs)
#        bar(x, height, width, *, align='center', **kwargs)
#        bar(x, height, width, bottom, *, align='center', **kwargs)
#
#     The bars are positioned at *x* with the given *align* ment. Their
#     dimensions are given by *width* and *height*. The vertical baseline
#     is *bottom* (default 0).
#
#     Each of *x*, *height*, *width*, and *bottom* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#
#     Parameters
#     ----------
#     x : sequence of scalars
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : scalar or sequence of scalars
#         The height(s) of the bars.
#
#     width : scalar or array-like, optional
# ...

# %%
movies.groupby('content_rating').values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-e6a6a78632e4> in <module>()
# ----> 1 movies.groupby('content_rating').values()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.518668 -0.148978
# 1  bar    one  0.442302 -1.279090
# 2  foo    two -0.529604 -0.827316
# 3  bar  three  0.141587  0.220783
# 4  foo    two  0.368907 -0.820353
# 5  bar    two  0.894426 -0.942256
# 6  foo    one -0.270919  0.673826
# 7  foo  three  0.066837  1.342851

# %%
def get_letter_type(letter):
    if letter.lower() in 'aeiou':
        return 'vowel'
    else:
        return 'consonant'

# %%
grouped = df.groupby(get_letter_type, axis=1)

# %%
grouped.count()
# Out:
#    consonant  vowel
# 0          3      1
# 1          3      1
# 2          3      1
# 3          3      1
# 4          3      1
# 5          3      1
# 6          3      1
# 7          3      1

# %%
grouped.first()
# Out:
#   consonant vowel
# 0       one   foo
# 1       one   bar
# 2       two   foo
# 3     three   bar
# 4       two   foo
# 5       two   bar
# 6       one   foo
# 7     three   foo

# %%
grouped.last()
# Out:
#    consonant vowel
# 0  -0.148978   foo
# 1  -1.279090   bar
# 2  -0.827316   foo
# 3   0.220783   bar
# 4  -0.820353   foo
# 5  -0.942256   bar
# 6   0.673826   foo
# 7   1.342851   foo

# %%
grouped.groups
# Out:
# {'consonant': Index(['B', 'C', 'D'], dtype='object'),
#  'vowel': Index(['A'], dtype='object')}

# %%
plt.plot(movies.groupby('content_rating'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-4a68d6aedef9> in <module>()
# ----> 1 plt.plot(movies.groupby('content_rating'))
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
# ...

# %%
df.plot()

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.content_rating.value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
ts=pd.Series(movies.content_rating.value_counts())

# %%
ts
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
type(movies.content_rating.value_counts())
# Out:
# pandas.core.series.Series

# %%
ts.get_values()
# Out:
# array([460, 189, 123,  65,  47,  38,  32,   7,   7,   4,   3,   1])

# %%
#plt.bar(x=ts.index.values, height=ts.get_values(),width=0.35)
ts.plot(kind='bar')
plt.xlabel("Content rating")
plt.ylabel("Number of movies")
plt.title("Moves by content rating")
plt.xticks
# Out:
# <function matplotlib.pyplot.xticks(*args, **kwargs)>

# %%
movies.iloc[0]
# Out:
# star_rating                                                     9.3
# title                                      The Shawshank Redemption
# content_rating                                                    R
# genre                                                         Crime
# duration                                                        142
# actors_list       [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# Name: 0, dtype: object

# %%
movies.head(1)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
ts.plot(kind='bar')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[movies['content_rating'] == 'NOT RATED' ] = 'UNRATED'

# %%
y = (1,2,3,[5,3,4],[3,5],[5,3])
x = [5,3]
any( x == e for e in y)
# Out:
# True

# %%
movies[movies['content_rating'] == 'NOT RATED' ] = 'UNRATED'
movies[movies['content_rating'] == 'APPROVED' ] = 'UNRATED'
movies[movies['content_rating'] == 'PASSED' ] = 'UNRATED'
movies[movies['content_rating'] == 'GP' ] = 'UNRATED'
movies[movies['content_rating'] == 'X' ] = 'NC-17'
movies[movies['content_rating'] == 'TV-MA' ] = 'NC-17'

# %%
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17       12
# Name: content_rating, dtype: int64

# %%
movies.content_rating.count()
# Out:
# 976

# %%
movies.loc[lambda df: df.content_rating.isin( ['NOT RATED','APPROVED','PASSED','GP']) , 'content_rating'] = 'UNRATED'

# %%
movies[movies.content_rating.isin( ['NOT RATED','APPROVED','PASSED','GP'])]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
movies[movies.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    160
# PG         123
# G           32
# NC-17        7
# X            4
# TV-MA        1
# Name: content_rating, dtype: int64

# %%
movies.loc[lambda df: df.content_rating.isnull(), 'content_rating'] = 'UNRATED'

# %%
movies.content_rating.value_counts()
# Out:
# R          460
# PG-13      189
# UNRATED    163
# PG         123
# G           32
# NC-17        7
# X            4
# TV-MA        1
# Name: content_rating, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    979 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
movies[movies.duration >= 120].star_rating.mean()
# Out:
# 7.948898678414082

# %%
movies[movies.duration < 120].star_rating.mean()
# Out:
# 7.838666666666657

# %%
movies.plot(x='duration', y='star_rating', kind='scatter')

# %%
movies.groupby(by='genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
mg = movies.groupby('content_rating').duration.agg(['max','min','mean', 'count'])

# %%
mg
# Out:
#                 max  min        mean  count
# content_rating
# G               238   75  112.343750     32
# NC-17           179   85  119.857143      7
# PG              224   76  115.300813    123
# PG-13           242   78  127.195767    189
# R               229   69  122.163043    460
# TV-MA           131  131  131.000000      1
# UNRATED         220   64  116.760736    163
# X               136   84  106.250000      4

# %%
mg.plot(kind='bar')

# %%
movies.groupby('content_rating').duration.agg(['max','min','mean']).plot(kind='bar'); plt.ylabel('Duration')
# Out:
# Text(0,0.5,'Duration')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.groupby('genre').describe()
# Out:
#           duration                                                       \
#              count        mean        std    min     25%    50%     75%
# genre
# Action       136.0  126.485294  21.982480   80.0  111.00  125.0  137.00
# Adventure     75.0  134.840000  33.383942   89.0  109.00  127.0  151.50
# Animation     62.0   96.596774  13.975927   75.0   87.00   94.5  102.00
# Biography     77.0  131.844156  24.283991   85.0  116.00  127.0  146.00
# Comedy       156.0  107.602564  20.101574   68.0   94.00  104.0  117.00
# Crime        124.0  122.298387  25.054406   67.0  104.75  118.0  134.25
# Drama        278.0  126.539568  25.637086   64.0  108.00  123.0  138.00
# Family         2.0  107.500000  10.606602  100.0  103.75  107.5  111.25
# Fantasy        1.0  112.000000        NaN  112.0  112.00  112.0  112.00
# Film-Noir      3.0   97.333333  12.096832   88.0   90.50   93.0  102.00
# History        1.0   66.000000        NaN   66.0   66.00   66.0   66.00
# ...

# %%
movies.sort_values(['genre','star_rating'], ascending=[True, False]).groupby('genre').first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
grpd = movies.sort_values(['genre','star_rating']).groupby('genre')

# %%
help(grpd.last())
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    979 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
mgt = movies.groupby('title').actors_list.count()

# %%
mgt[mgt > 1]
# Out:
# title
# Dracula                            2
# Les Miserables                     2
# The Girl with the Dragon Tattoo    2
# True Grit                          2
# Name: actors_list, dtype: int64

# %%
movies[movies.title.duplicated(keep=False)]
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula        UNRATED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit        UNRATED  Adventure
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 662       110  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# ...

# %%
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
movies[movies.title == 'Dracula']
# Out:
#      star_rating    title content_rating   genre  duration  \
# 703          7.6  Dracula        UNRATED  Horror        85
# 905          7.5  Dracula              R  Horror       128
#
#                                            actors_list
# 703  [u'Bela Lugosi', u'Helen Chandler', u'David Ma...
# 905  [u'Gary Oldman', u'Winona Ryder', u'Anthony Ho...

# %%
mgv = movies.genre.value_counts()

# %%
type(mgv)
# Out:
# pandas.core.series.Series

# %%
mgv [mgv > 10].index
# Out:
# Index(['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure',
#        'Animation', 'Horror', 'Mystery'],
#       dtype='object')

# %%
genres_with_more_than_ten_movies = ['Drama','Comedy','Action','Crime','Biography','Adventure','Animation','Horror','Mystery']

# %%
mgv [genres_with_more_than_ten_movies]
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Name: genre, dtype: int64

# %%
movies[movies.genre.isin(genres_with_more_than_ten_movies)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %%
movies[movies.genre.isin(list(mgv[mgv > 10].index))].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %%
list(mgv[mgv > 10].index)
# Out:
# ['Drama',
#  'Comedy',
#  'Action',
#  'Crime',
#  'Biography',
#  'Adventure',
#  'Animation',
#  'Horror',
#  'Mystery']

# %%
mgsg = movies.groupby('genre').star_rating.mean()

# %%
mgsg
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Family       7.850000
# Fantasy      7.700000
# Film-Noir    8.033333
# History      8.000000
# Horror       7.806897
# Mystery      7.975000
# Sci-Fi       7.920000
# Thriller     7.680000
# Western      8.255556
# Name: star_rating, dtype: float64

# %%
 (movies.groupby('genre').star_rating.count()) > 10
# Out:
# genre
# Action        True
# Adventure     True
# Animation     True
# Biography     True
# Comedy        True
# Crime         True
# Drama         True
# Family       False
# Fantasy      False
# Film-Noir    False
# History      False
# Horror        True
# Mystery       True
# Sci-Fi       False
# Thriller     False
# Western      False
# Name: star_rating, dtype: bool

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
al = list(movies.actors_list.values)

# %%
len(al)
# Out:
# 979
